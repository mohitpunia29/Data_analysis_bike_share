# %%
import matplotlib.pyplot as plt

import numpy as np
import pandas as pd
import statistics as st

df_2017 =  pd.read_csv ('./google_coding/2017-fordgobike-tripdata.csv')
df_201801 =  pd.read_csv ('./google_coding/201801-fordgobike-tripdata.csv')
df_201802 =  pd.read_csv ('./google_coding/201802-fordgobike-tripdata.csv')
df_201803 =  pd.read_csv ('./google_coding/201803-fordgobike-tripdata.csv')
df_201804 =  pd.read_csv ('./google_coding/201804-fordgobike-tripdata.csv')
df_201805 =  pd.read_csv ('./google_coding/201805-fordgobike-tripdata.csv')

df_2018 = df_201801+df_201802+df_201803+df_201804+df_201805
# Out:
#     duration_sec                start_time                  end_time  \
# 0          80110  2017-12-31 16:57:39.6540  2018-01-01 15:12:50.2450
# 1          78800  2017-12-31 15:56:34.8420  2018-01-01 13:49:55.6170
# 2          45768  2017-12-31 22:45:48.4110  2018-01-01 11:28:36.8830
# 3          62172  2017-12-31 17:31:10.6360  2018-01-01 10:47:23.5310
# 4          43603  2017-12-31 14:23:14.0010  2018-01-01 02:29:57.5710
# 5           9226  2017-12-31 22:51:00.9180  2018-01-01 01:24:47.1660
# 6           4507  2017-12-31 23:49:28.4220  2018-01-01 01:04:35.6190
# 7           4334  2017-12-31 23:46:37.1960  2018-01-01 00:58:51.2110
# 8           4150  2017-12-31 23:37:07.5480  2018-01-01 00:46:18.3080
# 9           4238  2017-12-31 23:35:38.1450  2018-01-01 00:46:17.0530
# 10          3292  2017-12-31 23:46:32.4030  2018-01-01 00:41:24.6050
# 11          3177  2017-12-31 23:48:11.7570  2018-01-01 00:41:09.5810
# 12          2183  2017-12-31 23:52:55.5810  2018-01-01 00:29:18.7430
# ...

# %%
fig = plt.figure(figsize=(15, 15))
fig.subplots_adjust(hspace=0.3, wspace= 0.2)
plt.subplot(3,2,1)
plt.title("Trip duration with Start Stations ids 2017")
map = {}
for index, id in enumerate(df_2017['start_station_id']):
    if id in map:
        map[id] += df_2017['duration_sec'][index] 
    else:
        map[id] = df_2017['duration_sec'][index]

X = np.arange(len(map))
plt.bar(X, map.values(), align='center')

plt.subplot(3,2,2)
plt.title("Trip duration with Start Stations ids January 2018")
map1 = {}
for index, id in enumerate(df_201801['start_station_id']):
    if id in map1:
        map1[id] += df_201801['duration_sec'][index] 
    else:
        map1[id] = df_201801['duration_sec'][index]

X = np.arange(len(map1))
plt.bar(X, map1.values(), align='center')

plt.subplot(3,2,3)

plt.title("Trip duration with Start Stations ids Feburary 2018")
map2 = {}
for index, id in enumerate(df_201802['start_station_id']):
    if id in map2:
        map2[id] += df_201802['duration_sec'][index] 
    else:
        map2[id] = df_201802['duration_sec'][index]

X = np.arange(len(map2))
plt.bar(X, map2.values(), align='center')

plt.subplot(3,2,4)
plt.title("Trip duration with Start Stations ids March 2018")
map3 = {}
for index, id in enumerate(df_201803['start_station_id']):
    if id in map3:
        map3[id] += df_201803['duration_sec'][index] 
    else:
        map3[id] = df_201803['duration_sec'][index]

X = np.arange(len(map3))
plt.bar(X, map3.values(), align='center')


plt.subplot(3,2,5)
plt.title("Trip duration with Start Stations ids April 2018")
map4 = {}
for index, id in enumerate(df_201804['start_station_id']):
    if id in map4:
        map4[id] += df_201804['duration_sec'][index] 
    else:
        map4[id] = df_201804['duration_sec'][index]

X = np.arange(len(map4))

plt.bar(X, map4.values(), align='center')


plt.subplot(3,2,6)
plt.title("Trip duration with Start Stations ids May 2018")
map5 = {}
for index, id in enumerate(df_201805['start_station_id']):
    if id in map5:
        map5[id] += df_201805['duration_sec'][index] 
    else:
        map5[id] = df_201805['duration_sec'][index]

X = np.arange(len(map5))
plt.bar(X, map5.values(), align='center')

print("Average is {0} and standard deviation is {1} of time duration in 2017".format(st.mean(df_2017['duration_sec']), st.pstdev(df_2017['duration_sec'])))

print("Average is {0} and standard deviation is {1} of time duration in January 2018".format(st.mean(df_201801['duration_sec']), st.pstdev(df_201801['duration_sec'])))
print("Average is {0} and standard deviation is {1} of time duration in Feburary 2018".format(st.mean(df_201802['duration_sec']), st.pstdev(df_201802['duration_sec'])))
print("Average is {0} and standard deviation is {1} of time duration in March 2018".format(st.mean(df_201803['duration_sec']), st.pstdev(df_201803['duration_sec'])))
print("Average is {0} and standard deviation is {1} of time duration in April 2018".format(st.mean(df_201804['duration_sec']), st.pstdev(df_201804['duration_sec'])))
print("Average is {0} and standard deviation is {1} of time duration in May 2018".format(st.mean(df_201805['duration_sec']), st.pstdev(df_201805['duration_sec'])))
# Out:
# Average is 1099.0095208774294 and standard deviation is 3444.1431376548753 of time duration in 2017
# Average is 870.935929621738 and standard deviation is 2550.5834386016068 of time duration in January 2018
# Average is 878.661912704511 and standard deviation is 2665.9519688511346 of time duration in Feburary 2018
# Average is 870.6498985473415 and standard deviation is 2524.6277889041726 of time duration in March 2018
# Average is 885.9273685093276 and standard deviation is 2697.7495239375194 of time duration in April 2018
# Average is 854.9043461270063 and standard deviation is 2396.546466907127 of time duration in May 2018

# %%
fig = plt.figure(figsize=(15, 50))
fig.subplots_adjust(hspace=0.3, wspace= 0.1)
plt.subplot(6,2,1)
plt.title("Probability of Start Stations ids 2017")
n, bins, patches = plt.hist(df_2017['start_station_id'], 272, density=True, facecolor='g', alpha=0.75)
plt.subplot(6,2,2)
plt.title("Probability of End Stations ids 2017")
n, bins, patches = plt.hist(df_2017['end_station_id'], 272, density=True, facecolor='g', alpha=0.75)
plt.subplot(6,2,3)
plt.title("Probability of Start Stations ids January 2018")
n, bins, patches = plt.hist(df_201801['start_station_id'], 272, density=True, facecolor='g', alpha=0.75)
plt.subplot(6,2,4)
plt.title("Probability of End Stations ids January 2018")
n, bins, patches = plt.hist(df_201801['end_station_id'], 272, density=True, facecolor='g', alpha=0.75)
plt.subplot(6,2,5)
plt.title("Probability of Start Stations ids Feburary 2018")
n, bins, patches = plt.hist(df_201802['start_station_id'], 272, density=True, facecolor='g', alpha=0.75)
plt.subplot(6,2,6)
plt.title("Probability of End Stations ids Feburary 2018")
n, bins, patches = plt.hist(df_201802['end_station_id'], 272, density=True, facecolor='g', alpha=0.75)
plt.subplot(6,2,7)
plt.title("Probability of Start Stations ids March 2018")
n, bins, patches = plt.hist(df_201803['start_station_id'], 272, density=True, facecolor='g', alpha=0.75)
plt.subplot(6,2,8)
plt.title("Probability of End Stations ids March 2018")
n, bins, patches = plt.hist(df_201803['end_station_id'], 272, density=True, facecolor='g', alpha=0.75)
plt.subplot(6,2,9)
plt.title("Probability of Start Stations ids April 2018")
n, bins, patches = plt.hist(df_201804['start_station_id'], 272, density=True, facecolor='g', alpha=0.75)
plt.subplot(6,2,10)
plt.title("Probability of End Stations ids April 2018")
n, bins, patches = plt.hist(df_201804['end_station_id'], 272, density=True, facecolor='g', alpha=0.75)
plt.subplot(6,2,11)
plt.title("Probability of Start Stations ids May 2018")
n, bins, patches = plt.hist(df_201805['start_station_id'], 272, density=True, facecolor='g', alpha=0.75)
plt.subplot(6,2,12)
plt.title("Probability of End Stations ids May 2018")
n, bins, patches = plt.hist(df_201805['end_station_id'], 272, density=True, facecolor='g', alpha=0.75)

# %%
avg_dur_2017= st.mean(df_2017['duration_sec'])
avg_dur_201801= st.mean(df_201801['duration_sec'])
avg_dur_201802= st.mean(df_201802['duration_sec'])
avg_dur_201803= st.mean(df_201803['duration_sec'])
avg_dur_201804= st.mean(df_201804['duration_sec'])
avg_dur_201805= st.mean(df_201805['duration_sec'])
avg_dur_2018= st.mean(df_2018['duration_sec'])


print(" Average Duration of travel in 2017", avg_dur_2017)
print(" Average Duration of travel in January 2018", avg_dur_201801)
print(" Average Duration of travel in Feburary 2018", avg_dur_201802)
print(" Average Duration of travel in March 2018", avg_dur_201803)
print(" Average Duration of travel in April 2018", avg_dur_201804)
print(" Average Duration of travel in May 2018", avg_dur_201805)
#print(" Average Duration of travel in 2018", avg_dur_2018)

print("It can be said that, 2017 was busiest year than 2018 and if situation were same as like 2018, then probably people will commute in fall 2018 and Summer 2018")
# Out:
#  Average Duration of travel in 2017 1099.0095208774294
#  Average Duration of travel in January 2018 870.935929621738
#  Average Duration of travel in Feburary 2018 878.661912704511
#  Average Duration of travel in March 2018 870.6498985473415
#  Average Duration of travel in April 2018 885.9273685093276
#  Average Duration of travel in May 2018 854.9043461270063
# It can be said that, 2017 was busiest year than 2018 and if situation were same as like 2018, then probably people will commute in fall 2018 and Summer 2018

# %%
print("Most common start station in 2017",st.mode(df_2017['start_station_name']))  # Most frequent start station
print("Most common end station in 2017",st.mode(df_2017['end_station_name']))  # Most frequent end station
print("Most common start station in 2018 January",st.mode(df_201801['start_station_name']))  # Most frequent start station
print("Most common end station in 2018 January",st.mode(df_201801['end_station_name'])) 
print("Most common start station in 2018 Feburary",st.mode(df_201802['start_station_name']))  # Most frequent start station
print("Most common end station in 2018 Feburary",st.mode(df_201802['end_station_name'])) 
print("Most common start station in 2018 March",st.mode(df_201803['start_station_name']))  # Most frequent start station
print("Most common end station in 2018 March",st.mode(df_201803['end_station_name'])) 
print("Most common start station in 2018 April",st.mode(df_201804['start_station_name']))  # Most frequent start station
print("Most common end station in 2018 April",st.mode(df_201804['end_station_name'])) 
print("Most common start station in 2018 May",st.mode(df_201805['start_station_name']))  # Most frequent start station
print("Most common end station in 2018 May",st.mode(df_201805['end_station_name'])) 


# Common Start Station in 2017 was San Francisco Ferry Building and end station was San Francisco Caltrain

# In 2018 Januray Start Station and end station was San Francisco Cal Train
# In Feburary 2018, Start Station and End station were same as of January
# In March 2018, Start Station was San Francisco Ferry Building and end station was San Francisco Caltrain
# In April 2018 start station and end station was same as in march
# In May 2018, start station and end station was San Francisco Ferry Building
# Out:
# Most common start station in 2017 San Francisco Ferry Building (Harry Bridges Plaza)
# Most common end station in 2017 San Francisco Caltrain (Townsend St at 4th St)
# Most common start station in 2018 January San Francisco Caltrain (Townsend St at 4th St)
# Most common end station in 2018 January San Francisco Caltrain (Townsend St at 4th St)
# Most common start station in 2018 Feburary San Francisco Caltrain (Townsend St at 4th St)
# Most common end station in 2018 Feburary San Francisco Caltrain (Townsend St at 4th St)
# Most common start station in 2018 March San Francisco Ferry Building (Harry Bridges Plaza)
# Most common end station in 2018 March San Francisco Caltrain (Townsend St at 4th St)
# Most common start station in 2018 April San Francisco Ferry Building (Harry Bridges Plaza)
# Most common end station in 2018 April San Francisco Caltrain Station 2  (Townsend St at 4th St)
# Most common start station in 2018 May San Francisco Ferry Building (Harry Bridges Plaza)
# ...

# %% [markdown]
# # It can be said, most of the population is living and working in san francisco

# %%
# for 2017
station_start_freq= st.mode(df_2017['start_station_name'])
most_freq_station_dur_2017=[]
end_station_most_freq_start_station_2017=[]
population_type_2017=[]
birth_year_most_freq_2017=[]
bike_share_most_freq_2017=[]
user_type_most_freq_2017=[]
for counter, value in enumerate(df_2017["start_station_name"]):
    if value == station_start_freq:
        most_freq_station_dur_2017.append(df_2017["duration_sec"][counter])
        end_station_most_freq_start_station_2017.append(df_2017["end_station_name"][counter])
        population_type_2017.append(df_2017["member_gender"][counter])
        birth_year_most_freq_2017.append(df_2017["member_birth_year"][counter])
        user_type_most_freq_2017.append(df_2017["user_type"][counter])

# %%
# for 2017

count_female=0
count_male=0
female_cust=0
male_cust=0
for counter, value in enumerate(population_type_2017):
    if value == "Female":
        count_female+=1
        if user_type_most_freq_2017[counter] == "Customer":
            female_cust+=1
        
    if value== "Male":
        count_male+=1
        if user_type_most_freq_2017[counter] == "Customer":
            male_cust+=1
        
        
print("Total of female starting from San Francisco", count_female )
print("Total of male starting from San Francisco", count_male )
print("Total of male starting from San Francisco are customer", male_cust )
print("Total of female starting from San Francisco are customer", female_cust )
print("Total of male starting from San Francisco are subscriber", count_male- male_cust )
print("Total of female starting from San Francisco are subscriber", count_female - female_cust )
# Out:
# Total of female starting from San Francisco 2819
# Total of male starting from San Francisco 8586
# Total of male starting from San Francisco are customer 917
# Total of female starting from San Francisco are customer 604
# Total of male starting from San Francisco are subscriber 7669
# Total of female starting from San Francisco are subscriber 2215

# %%
#for 2018

most_freq_station_dur_201801=[]
fre_st_201801= st.mode(df_201801['start_station_name'])
end_station_most_freq_start_station_201801=[]
population_type_201801=[]
birth_year_most_freq_201801=[]
male_201801=0
male_customer_201801=0
female_customer_201801=0
female_201801=0
bikeshare_male_201801=0
bikeshare_female_201801=0
bikeshare_201801=0
user_type_most_freq_201801=[]
for counter, value in enumerate(df_201801["start_station_name"]):
    if value == fre_st_201801:
        most_freq_station_dur_201801.append(df_201801["duration_sec"][counter])
        end_station_most_freq_start_station_201801.append(df_201801["end_station_name"][counter])
        population_type_201801.append(df_201801["member_gender"][counter])
        if df_201801["member_gender"][counter]== 'Male':
            male_201801+=1
            if df_201801["user_type"][counter]== 'Customer':
                male_customer_201801+=1
        if df_201801["member_gender"][counter]== 'Female':
            female_201801+=1
            if df_201801["user_type"][counter]== 'Customer':
                female_customer_201801+=1
        birth_year_most_freq_201801.append(df_201801["member_birth_year"][counter])
        user_type_most_freq_201801.append(df_201801["user_type"][counter])
        if df_201801["bike_share_for_all_trip"][counter]== 'Yes':
            bikeshare_201801+=1
            if df_201801["member_gender"][counter]== 'Female':
                bikeshare_female_201801+=1
            if df_201801["member_gender"][counter]== 'Male':
                bikeshare_male_201801+=1
        

most_freq_station_dur_201802=[]
end_station_most_freq_start_station_201802=[]
fre_st_201802= st.mode(df_201802['start_station_name'])
population_type_201802=[]
birth_year_most_freq_201802=[]
male_201802=0
male_Customer_201802=0
female_Customer_201802=0
female_201802=0
user_type_most_freq_201802=[]
bikeshare_male_201802=0
bikeshare_female_201802=0
bikeshare_201802=0
for counter, value in enumerate(df_201802["start_station_name"]):
    if value == fre_st_201802:
        most_freq_station_dur_201802.append(df_201802["duration_sec"][counter])
        end_station_most_freq_start_station_201802.append(df_201802["end_station_name"][counter])
        population_type_201802.append(df_201802["member_gender"][counter])
        if df_201802["member_gender"][counter]== 'Male':
            male_201802+=1
            if df_201802["user_type"][counter]== 'Customer':
                male_Customer_201802+=1
        if df_201802["member_gender"][counter]== 'Female':
            female_201802+=1
            if df_201802["user_type"][counter]== 'Customer':
                female_Customer_201802+=1
        if df_201802["bike_share_for_all_trip"][counter]== 'Yes':
            bikeshare_201802+=1
            if df_201802["member_gender"][counter]== 'Female':
                bikeshare_female_201802+=1
            if df_201802["member_gender"][counter]== 'Male':
                bikeshare_male_201802+=1
        birth_year_most_freq_201802.append(df_201802["member_birth_year"][counter])
        user_type_most_freq_201802.append(df_201802["user_type"][counter])
        
most_freq_station_dur_201803=[]
end_station_most_freq_start_station_201803=[]
fre_st_201803= st.mode(df_201803['start_station_name'])
population_type_201803=[]
birth_year_most_freq_201803=[]
male_201803=0
male_Customer_201803=0
female_Customer_201803=0
bikeshare_male_201803=0
bikeshare_female_201803=0
bikeshare_201803=0
female_201803=0
user_type_most_freq_201803=[]
for counter, value in enumerate(df_201803["start_station_name"]):
    if value == fre_st_201803:
        most_freq_station_dur_201803.append(df_201803["duration_sec"][counter])
        end_station_most_freq_start_station_201803.append(df_201803["end_station_name"][counter])
        population_type_201803.append(df_201803["member_gender"][counter])
        if df_201803["member_gender"][counter]== 'Male':
            male_201803+=1
            if df_201803["user_type"][counter]== 'Customer':
                male_Customer_201803+=1
        if df_201803["member_gender"][counter]== 'Female':
            female_201803+=1
            if df_201803["user_type"][counter]== 'Customer':
                female_Customer_201803+=1
        birth_year_most_freq_201803.append(df_201803["member_birth_year"][counter])
        user_type_most_freq_201803.append(df_201803["user_type"][counter])
        if df_201803["bike_share_for_all_trip"][counter]== 'Yes':
            bikeshare_201803+=1
            if df_201803["member_gender"][counter]== 'Female':
                bikeshare_female_201803+=1
            if df_201803["member_gender"][counter]== 'Male':
                bikeshare_male_201803+=1

most_freq_station_dur_201804=[]
end_station_most_freq_start_station_201804=[]
population_type_201804=[]
fre_st_201804= st.mode(df_201804['start_station_name'])
birth_year_most_freq_201804=[]
male_201804=0
male_Customer_201804=0
female_Customer_201804=0
bikeshare_male_201804=0
bikeshare_female_201804=0
bikeshare_201804=0
female_201804=0
user_type_most_freq_201804=[]
for counter, value in enumerate(df_201804["start_station_name"]):
    if value == fre_st_201804:
        most_freq_station_dur_201804.append(df_201804["duration_sec"][counter])
        end_station_most_freq_start_station_201804.append(df_201804["end_station_name"][counter])
        population_type_201804.append(df_201804["member_gender"][counter])
        if df_201804["member_gender"][counter]== 'Male':
            male_201804+=1
            if df_201804["user_type"][counter]== 'Customer':
                male_Customer_201804+=1
            
        if df_201804["member_gender"][counter]== 'Female':
            female_201804+=1
            if df_201804["user_type"][counter]== 'Customer':
                female_Customer_201804+=1
        birth_year_most_freq_201804.append(df_201804["member_birth_year"][counter])
        user_type_most_freq_201804.append(df_201804["user_type"][counter])
        if df_201804["bike_share_for_all_trip"][counter]== 'Yes':
            bikeshare_201804+=1
            if df_201804["member_gender"][counter]== 'Female':
                bikeshare_female_201804+=1
            if df_201804["member_gender"][counter]== 'Male':
                bikeshare_male_201804+=1
        
        
most_freq_station_dur_201805=[]
end_station_most_freq_start_station_201805=[]
population_type_201805=[]
birth_year_most_freq_201805=[]
fre_st_201805= st.mode(df_201805['start_station_name'])
male_201805=0
bikeshare_male_201805=0
bikeshare_female_201805=0
bikeshare_201805=0
male_Customer_201805=0
female_Customer_201805=0
female_201805=0
user_type_most_freq_201805=[]
for counter, value in enumerate(df_201805["start_station_name"]):
    if value == fre_st_201805:
        most_freq_station_dur_201805.append(df_201805["duration_sec"][counter])
        end_station_most_freq_start_station_201805.append(df_201805["end_station_name"][counter])
        population_type_201805.append(df_201805["member_gender"][counter])
        if df_201805["member_gender"][counter]== 'Male':
            male_201805+=1
            if df_201805["user_type"][counter]== 'Customer':
                male_Customer_201805+=1
        if df_201805["member_gender"][counter]== 'Female':
            female_201805+=1
            if df_201805["user_type"][counter]== 'Customer':
                female_Customer_201805+=1
        birth_year_most_freq_201805.append(df_201805["member_birth_year"][counter])
        user_type_most_freq_201805.append(df_201805["user_type"][counter])
        if df_201805["bike_share_for_all_trip"][counter]== 'Yes':
            bikeshare_201805+=1
            if df_201805["member_gender"][counter]== 'Female':
                bikeshare_female_201805+=1
            if df_201805["member_gender"][counter]== 'Male':
                bikeshare_male_201805+=1

# %%
import pandas as pd
a = [count_female, count_female-female_cust, count_male, count_male-male_cust]
a_201801= [male_201801, male_201801-male_customer_201801,female_201801, female_201801-female_customer_201801]
a_201802= [male_201802, male_201802-male_Customer_201802,female_201802, female_201802-female_Customer_201802]
a_201803= [male_201803, male_201803-male_Customer_201803,female_201803, female_201803-female_Customer_201803]
a_201804= [male_201804, male_201804-male_Customer_201804,female_201804, female_201804-female_Customer_201804]
a_201805= [male_201805, male_201805-male_Customer_201805,female_201805, female_201805-female_Customer_201805]
fig = plt.figure(figsize=(12, 12))

plt.subplot(3,2,1)
fig.subplots_adjust(hspace=0.8)
plt.bar(['female','Female Subscriber','male', 'male Subscriber'],a)
plt.title("Population at Most common station in 2017")
plt.subplot(3,2,2)
plt.bar(['male','male Subscriber','female', 'female Subscriber'],a_201801)
plt.title("Population at Most common station in January 2018")
plt.subplot(3,2,3)
plt.bar(['male','male Subscriber','female', 'female Subscriber'],a_201802)
plt.title(" Population at Most common station in Feburary 2018")
plt.subplot(3,2,4)
plt.bar(['male','male Subscriber','female', 'female Subscriber'],a_201803)
plt.title("Population at Most common station in March 2018")
plt.subplot(3,2,5)
plt.bar(['male','male Subscriber','female', 'female Subscriber'],a_201804)
plt.title("Population at Most common station in April 2018")
plt.subplot(3,2,6)
plt.bar(['male','male Subscriber','female', 'female Subscriber'],a_201805)
plt.title("Population at Most common station in May 2018")


plt.show()

# %% [markdown]
# # Always Male population was more than female population, ratio of male population to subscriber male was more than female population to female subscriber. It can be said, population of male subscribers commuting common station is more than population of female subscribers, therefore, there are more working males than females.

# %% [markdown]
# # Bike Share Below Computed was for population which used most common station in 2017 as well as 2018

# %%
b_201801= [bikeshare_201801, bikeshare_female_201801,bikeshare_male_201801]
b_201802= [bikeshare_201802, bikeshare_female_201802,bikeshare_male_201802]
b_201803= [bikeshare_201803, bikeshare_female_201803,bikeshare_male_201803]
b_201804= [bikeshare_201804, bikeshare_female_201804,bikeshare_male_201804]
b_201805= [bikeshare_201805, bikeshare_female_201805,bikeshare_male_201805]

fig = plt.figure(figsize=(12, 12))
fig.subplots_adjust(hspace=1.0)
plt.subplot(3,2,1)
plt.bar(['Total Bike Share','female','male'],b_201801)
plt.title("Bike Shares in January 2018")
plt.subplot(3,2,2)
plt.bar(['Total Bike Share','female','male'],b_201802)
plt.title("Bike Shares in Feburary 2018")
plt.subplot(3,2,3)
plt.bar(['Total Bike Share','female','male'],b_201803)
plt.title("Bike Shares in March 2018")
plt.subplot(3,2,4)
plt.bar(['Total Bike Share','female','male'],b_201804)
plt.title("Bike Shares in April 2018")
plt.subplot(3,2,5)
plt.bar(['Total Bike Share','female','male'],b_201805)
plt.title("Bike Shares in May 2018")


plt.show()

# %% [markdown]
# # Use of Bike share by female gradually increased

# %%
busydays_2017=[]
busydays_201801=[]
busydays_201802=[]
busydays_201803=[]
busydays_201804=[]
busydays_201805=[]
m1 = max(df_2017['duration_sec'])
m2 = max(df_201801['duration_sec'])
m3 = max(df_201802['duration_sec'])
m4 = max(df_201803['duration_sec'])
m5 = max(df_201804['duration_sec'])
m6 = max(df_201805['duration_sec'])
for i, value in enumerate(df_2017['duration_sec']):
    if value == m1:
        busydays_2017.append(df_2017['start_time'][i])
        busydays_2017.append(df_2017['end_time'][i])
        
for i, value in enumerate(df_201801['duration_sec']):
    if value == m2:
        busydays_201801.append(df_201801['start_time'][i])
        busydays_201801.append(df_201801['end_time'][i])

for i, value in enumerate(df_201802['duration_sec']):
    if value == m3:
        busydays_201802.append(df_201802['start_time'][i])
        busydays_201802.append(df_201802['end_time'][i])
        
for i, value in enumerate(df_201803['duration_sec']):
    if value == m4:
        busydays_201803.append(df_201803['start_time'][i])
        busydays_201803.append(df_201803['end_time'][i])
        
for i, value in enumerate(df_201804['duration_sec']):
    if value == m5:
        busydays_201804.append(df_201804['start_time'][i])
        busydays_201804.append(df_201804['end_time'][i])

for i, value in enumerate(df_201805['duration_sec']):
    if value == m6:
        busydays_201805.append(df_201805['start_time'][i])
        busydays_201805.append(df_201805['end_time'][i])
        

    
print("Busiest date and time in 2017", busydays_2017)
print("Busiest date and time in January 2018", busydays_201801)
print("Busiest date and time in Feburary 2018", busydays_201802)
print("Busiest date and time in March 2018", busydays_201803)
print("Busiest date and time in April 2018", busydays_201804)
print("Busiest date and time in May 2018", busydays_201805)
# Out:
# Busiest date and time in 2017 ['2017-11-12 10:44:32.0430', '2017-11-13 10:44:01.8200']
# Busiest date and time in January 2018 ['2018-01-30 14:45:44.4800', '2018-01-31 14:31:31.0530']
# Busiest date and time in Feburary 2018 ['2018-02-03 17:32:04.0420', '2018-02-04 17:31:30.7880']
# Busiest date and time in March 2018 ['2018-03-31 11:28:07.6580', '2018-04-01 11:18:52.6130']
# Busiest date and time in April 2018 ['2018-04-30 16:07:13.9190', '2018-05-01 16:02:56.7170']
# Busiest date and time in May 2018 ['2018-05-27 13:23:34.3950', '2018-05-28 13:20:23.3170']

# %% [markdown]
# # Most busiest dates are either starting of the month or ending of month. It could be because, most of the population is working, they need to manage their attendence in the company. As Around month end, or starting month, salary is also transfered to employees.

# %%
year1900_2017=0
year1920_2017=0
year1940_2017=0
year1960_2017=0
year1980_2017=0
year2000_2017=0
year2001_2017=0
for year in df_2017['member_birth_year']:
    if( year < 1900):
        year1900_2017+=1
    if ( year >= 1900) and (year< 1920):
        year1920_2017+=1
    if( year >= 1920) and (year< 1940):
        year1940_2017+=1
    if( year >= 1940) and (year< 1960):
        year1960_2017+=1
    if( year >= 1960) and (year< 1980):
        year1980_2017+=1
    if( year >= 1980) and (year< 2000):
        year2000_2017+=1   
    if( year >= 2000):
        year2001_2017+=1
    
year1900_201801=0
year1920_201801=0
year1940_201801=0
year1960_201801=0
year1980_201801=0
year2000_201801=0
year2001_201801=0
for year in df_201801['member_birth_year']:
    if( year < 1900):
        year1900_201801+=1
    if ( year >= 1900) and (year< 1920):
        year1920_201801+=1
    if( year >= 1920) and (year< 1940):
        year1940_201801+=1
    if( year >= 1940) and (year< 1960):
        year1960_201801+=1
    if( year >= 1960) and (year< 1980):
        year1980_201801+=1
    if( year >= 1980) and (year< 2000):
        year2000_201801+=1   
    if( year >= 2000):
        year2001_201801+=1
        
year1900_201802=0
year1920_201802=0
year1940_201802=0
year1960_201802=0
year1980_201802=0
year2000_201802=0
year2001_201802=0
for year in df_201802['member_birth_year']:
    if( year < 1900):
        year1900_201802+=1
    if ( year >= 1900) and (year< 1920):
        year1920_201802+=1
    if( year >= 1920) and (year< 1940):
        year1940_201802+=1
    if( year >= 1940) and (year< 1960):
        year1960_201802+=1
    if( year >= 1960) and (year< 1980):
        year1980_201802+=1
    if( year >= 1980) and (year< 2000):
        year2000_201802+=1   
    if( year >= 2000):
        year2001_201802+=1
        
year1900_201803=0
year1920_201803=0
year1940_201803=0
year1960_201803=0
year1980_201803=0
year2000_201803=0
year2001_201803=0
for year in df_201803['member_birth_year']:
    if( year < 1900):
        year1900_201803+=1
    if ( year >= 1900) and (year< 1920):
        year1920_201803+=1
    if( year >= 1920) and (year< 1940):
        year1940_201803+=1
    if( year >= 1940) and (year< 1960):
        year1960_201803+=1
    if( year >= 1960) and (year< 1980):
        year1980_201803+=1
    if( year >= 1980) and (year< 2000):
        year2000_201803+=1   
    if( year >= 2000):
        year2001_201803+=1
        
year1900_201804=0
year1920_201804=0
year1940_201804=0
year1960_201804=0
year1980_201804=0
year2000_201804=0
year2001_201804=0
for year in df_201804['member_birth_year']:
    if( year < 1900):
        year1900_201804+=1
    if ( year >= 1900) and (year< 1920):
        year1920_201804+=1
    if( year >= 1920) and (year< 1940):
        year1940_201804+=1
    if( year >= 1940) and (year< 1960):
        year1960_201804+=1
    if( year >= 1960) and (year< 1980):
        year1980_201804+=1
    if( year >= 1980) and (year< 2000):
        year2000_201804+=1   
    if( year >= 2000):
        year2001_201804+=1
        
year1900_201805=0
year1920_201805=0
year1940_201805=0
year1960_201805=0
year1980_201805=0
year2000_201805=0
year2001_201805=0
for year in df_201805['member_birth_year']:
    if( year < 1900):
        year1900_201805+=1
    if ( year >= 1900) and (year< 1920):
        year1920_201805+=1
    if( year >= 1920) and (year< 1940):
        year1940_201805+=1
    if( year >= 1940) and (year< 1960):
        year1960_201805+=1
    if( year >= 1960) and (year< 1980):
        year1980_201805+=1
    if( year >= 1980) and (year< 2000):
        year2000_201805+=1   
    if( year >= 2000):
        year2001_201805+=1
        
year1920_201801
# Out:
# 116

# %%
c_2017= [year1900_2017, year1920_2017,year1940_2017,year1960_2017,year1980_2017,year2000_2017,year2001_2017]
c_201801= [year1900_201801, year1920_201801,year1940_201801,year1960_201801,year1980_201801,year2000_201801,year2001_201801]
c_201802= [year1900_201802, year1920_201802,year1940_201802,year1960_201802,year1980_201802,year2000_201802,year2001_201802]
c_201803= [year1900_201803, year1920_201803,year1940_201803,year1960_201803,year1980_201803,year2000_201803,year2001_201803]
c_201804= [year1900_201804, year1920_201804,year1940_201804,year1960_201804,year1980_201804,year2000_201804,year2001_201804]
c_201805= [year1900_201805, year1920_201805,year1940_201805,year1960_201805,year1980_201805,year2000_201805,year2001_201805]

fig = plt.figure(figsize=(25, 20))
fig.subplots_adjust(hspace=0.5)
plt.subplot(3,2,1)
plt.bar(['Earlier 1900','1900-1920','1920-1940','1940-1960','1960-1980','1980-2000','Later 2000'],c_201801)
plt.title("Birth Year of Population in January 2018")
plt.subplot(3,2,2)
plt.bar(['Earlier 1900','1900-1920','1920-1940','1940-1960','1960-1980','1980-2000','Later 2000'],c_201802)
plt.title("Birth Year of Population in Feburary 2018")
plt.subplot(3,2,3)
plt.bar(['Earlier 1900','1900-1920','1920-1940','1940-1960','1960-1980','1980-2000','Later 2000'],c_201803)
plt.title("Birth Year of Population in March 2018")
plt.subplot(3,2,4)
plt.bar(['Earlier 1900','1900-1920','1920-1940','1940-1960','1960-1980','1980-2000','Later 2000'],c_201804)
plt.title("Birth Year of Population in April 2018")
plt.subplot(3,2,5)
plt.bar(['Earlier 1900','1900-1920','1920-1940','1940-1960','1960-1980','1980-2000','Later 2000'],c_201805)
plt.title("Birth Year of Population in May 2018")
plt.subplot(3,2,6)
plt.bar(['Earlier 1900','1900-1920','1920-1940','1940-1960','1960-1980','1980-2000','Later 2000'],c_2017)
plt.title("Birth Year of Population in 2017")
# Out:
# Text(0.5,1,'Birth Year of Population in 2017')

# %% [markdown]
# # Population born between 1980 to 2000 are most common commuters in 2017 as well as 2018
